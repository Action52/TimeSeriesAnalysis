# %%
import pandas as pd
from create_dataset import create_combined_dataset

# %% [markdown]
# ## Create dataset for MADRID-MEXICO flights

# %%
start_date = '2023-10-01'
end_date = '2023-11-10'
currency_pairs = ['EURMXN=X', 'EURTRY=X']
origin = 'MAD'
destination = 'MEX'
currency = 'EUR'

madmex = create_combined_dataset(start_date, end_date, currency_pairs, origin, destination, currency)
madmex
# Out:
# Error on 2023-10-09: Failed to retrieve flight price analysis
# Error on 2023-10-24: Failed to retrieve flight price analysis
# Error on 2023-11-01: Failed to retrieve flight price analysis
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#           date origin destination currency_code  minimum_price  \
# 0   2023-10-01    MAD         MEX           EUR          94.61
# 1   2023-10-02    MAD         MEX           EUR          94.61
# 2   2023-10-03    MAD         MEX           EUR          94.61
# 3   2023-10-04    MAD         MEX           EUR          94.61
# 4   2023-10-05    MAD         MEX           EUR          94.61
# 5   2023-10-06    MAD         MEX           EUR          94.61
# 6   2023-10-07    MAD         MEX           EUR          94.61
# 7   2023-10-08    MAD         MEX           EUR          94.61
# 8   2023-10-09    NaN         NaN           NaN            NaN
# ...

# %%
combined_df['median_price'].unique()
# Out:
# array([1340.44,     nan, 1385.29])

# %% [markdown]
# ## Create dataset for MADRID-ISTAMBUL flights

# %%
start_date = '2023-10-01'
end_date = '2023-11-10'
currency_pairs = ['EURMXN=X', 'EURTRY=X']
origin = 'MAD'
destination = 'IST'
currency = 'EUR'

madist = create_combined_dataset(start_date, end_date, currency_pairs, origin, destination, currency)
madist
# Out:
# Error on 2023-10-09: Failed to retrieve flight price analysis
# Error on 2023-10-11: Failed to retrieve flight price analysis
# Error on 2023-10-16: Failed to retrieve flight price analysis
# Error on 2023-11-04: Failed to retrieve flight price analysis
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#           date origin destination currency_code  minimum_price  \
# 0   2023-10-01    MAD         IST           EUR          81.63
# 1   2023-10-02    MAD         IST           EUR          81.63
# 2   2023-10-03    MAD         IST           EUR          81.63
# 3   2023-10-04    MAD         IST           EUR          81.63
# 4   2023-10-05    MAD         IST           EUR          81.63
# 5   2023-10-06    MAD         IST           EUR          81.63
# 6   2023-10-07    MAD         IST           EUR          81.63
# 7   2023-10-08    MAD         IST           EUR          81.63
# ...
