# %%
import pandas as pd
from create_dataset import create_combined_dataset

# %% [markdown]
# ## Create dataset for MADRID-MEXICO flights

# %%
start_date = '2019-01-01'
end_date = '2023-10-31'
currency_pairs = ['EURMXN=X', 'EURTRY=X', 'EURUSD=X']
origin = 'MAD'
destination = 'MEX'
currency = 'USD'

madmex = create_combined_dataset(start_date, end_date, currency_pairs, origin, destination, currency)
madmex.head()
# Out:
#   0%|          | 0/1765 [00:00<?, ?it/s]
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#          date origin destination currency_code  minimum_price  \
# 0  2019-01-01    MAD         MEX           USD         103.95
# 1  2019-01-02    MAD         MEX           USD         103.95
# 2  2019-01-03    MAD         MEX           USD         103.95
# 3  2019-01-04    NaN         NaN           NaN            NaN
# 4  2019-01-05    NaN         NaN           NaN            NaN
#
#    first_quartile_price  median_price  third_quartile_price  maximum_price  \
# 0               1160.14       1365.88               1736.12        1856.57
# 1               1160.14       1365.88               1736.12        1856.57
# 2               1160.14       1365.88               1736.12        1856.57
# 3                   NaN           NaN                   NaN            NaN
# 4                   NaN           NaN                   NaN            NaN
#
#    EURMXN=X_Close  EURTRY=X_Close  EURUSD=X_Close
# 0       22.524000         6.04694        1.149306
# 1       22.495399         6.05707        1.146171
# 2       22.207001         6.21404        1.131811
# 3       22.341801         6.22648        1.139108
# 4             NaN             NaN             NaN

# %%
madmex.describe()
# Out:
#        minimum_price  first_quartile_price  median_price  \
# count    1455.000000           1455.000000   1455.000000
# mean      108.344227           1298.441656   1536.298302
# std         2.975654            106.066430    106.528729
# min       103.950000           1158.440000   1351.370000
# 25%       103.950000           1160.910000   1461.010000
# 50%       109.510000           1325.610000   1516.860000
# 75%       111.080000           1406.350000   1600.540000
# max       111.280000           1474.630000   1708.420000
#
#        third_quartile_price  maximum_price  EURMXN=X_Close  EURTRY=X_Close  \
# count           1455.000000    1455.000000     1260.000000     1260.000000
# mean            1752.997485    1895.301973       22.207149       12.941429
# std               59.818438      40.512080        2.181717        6.827459
# min             1684.610000    1845.370000       18.064800        5.925860
# 25%             1706.160000    1856.570000       20.648075        7.004595
# 50%             1741.550000    1879.450000       21.733399        9.981010
# 75%             1811.320000    1931.890000       24.000226       18.138735
# max             1868.860000    1964.300000       27.304600       30.229389
#
#        EURUSD=X_Close
# count     1259.000000
# mean         1.117224
# std          0.057157
# min          0.959619
# 25%          1.083201
# 50%          1.115400
# 75%          1.161481
# max          1.234111

# %% [markdown]
# ## Create dataset for MADRID-ISTAMBUL flights

# %%
start_date = '2019-01-01'
end_date = '2023-10-31'
currency_pairs = ['EURMXN=X', 'EURTRY=X', 'EURUSD=X']
origin = 'MAD'
destination = 'IST'
currency = 'USD'

madist = create_combined_dataset(start_date, end_date, currency_pairs, origin, destination, currency)
madist
# Out:
#   0%|          | 0/1765 [00:00<?, ?it/s]
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#             date origin destination currency_code  minimum_price  \
# 0     2019-01-01    MAD         IST           USD          90.90
# 1     2019-01-02    MAD         IST           USD          90.90
# 2     2019-01-03    NaN         NaN           NaN            NaN
# 3     2019-01-04    MAD         IST           USD          90.90
# 4     2019-01-05    NaN         NaN           NaN            NaN
# ...          ...    ...         ...           ...            ...
# 1760  2023-10-27    MAD         IST           USD          95.84
# 1761  2023-10-28    MAD         IST           USD          95.84
# 1762  2023-10-29    NaN         NaN           NaN            NaN
# 1763  2023-10-30    MAD         IST           USD          95.84
# 1764  2023-10-31    NaN         NaN           NaN            NaN
#
#       first_quartile_price  median_price  third_quartile_price  maximum_price  \
# 0                   414.03        432.05                450.17         513.21
# 1                   414.03        432.05                450.17         513.21
# 2                      NaN           NaN                   NaN            NaN
# 3                   414.03        432.05                450.17         513.21
# 4                      NaN           NaN                   NaN            NaN
# ...                    ...           ...                   ...            ...
# 1760                489.68        504.83                525.20         581.13
# 1761                489.68        504.83                525.20         581.13
# 1762                   NaN           NaN                   NaN            NaN
# 1763                489.68        504.83                525.20         581.13
# 1764                   NaN           NaN                   NaN            NaN
#
#       EURMXN=X_Close  EURTRY=X_Close  EURUSD=X_Close
# 0          22.524000        6.046940        1.149306
# 1          22.495399        6.057070        1.146171
# 2          22.207001        6.214040        1.131811
# 3          22.341801        6.226480        1.139108
# 4                NaN             NaN             NaN
# ...              ...             ...             ...
# 1760       19.171900       29.737801        1.056446
# 1761             NaN             NaN             NaN
# 1762             NaN             NaN             NaN
# 1763       19.122299       29.786699        1.056245
# 1764             NaN             NaN             NaN
#
# [1765 rows x 12 columns]

# %%
madist.describe()
# Out:
#        minimum_price  first_quartile_price  median_price  \
# count    1472.000000           1472.000000   1472.000000
# mean       95.342649            462.365944    492.214742
# std         3.539595             31.818217     48.312452
# min        90.900000            414.030000    432.050000
# 25%        90.900000            425.850000    460.000000
# 50%        95.380000            457.090000    472.110000
# 75%        97.760000            489.680000    557.460000
# max       101.220000            519.010000    580.920000
#
#        third_quartile_price  maximum_price  EURMXN=X_Close  EURTRY=X_Close  \
# count           1472.000000    1472.000000     1260.000000     1260.000000
# mean             518.395367     567.675965       22.207149       12.941429
# std               44.688344      24.247478        2.181717        6.827459
# min              450.170000     513.210000       18.064800        5.925860
# 25%              478.890000     550.230000       20.648075        7.004595
# 50%              525.200000     569.740000       21.733399        9.981010
# 75%              573.110000     587.830000       24.000226       18.138735
# max              583.150000     604.220000       27.304600       30.229389
#
#        EURUSD=X_Close
# count     1259.000000
# mean         1.117224
# std          0.057157
# min          0.959619
# 25%          1.083201
# 50%          1.115400
# 75%          1.161481
# max          1.234111

# %% [markdown]
# ## Save the datasets

# %%
madmex.to_csv('madmex.csv', index=False)

# %%
madist.to_csv('madist.csv', index=False)
